# %%
from conversions import v7labstobasicjson
import os
import json
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %%
for file in os.listdir('data/json'):
    print(file)
    file1obj = v7labstobasicjson(os.path.join('data/json', file), os.path.join('data/basicjson', file))
    break
# Out:
# verydark1.json

# %%
file = 'pristine10.json'
filepath = os.path.join('data/images', os.path.splitext(file)[0] + '.jpg')
plt.imshow(Image.open(filepath))

# %%
with open(os.path.join('data/basicjson', file), 'r') as fp:
    json_data = json.load(fp)

image = Image.new('1', (json_data['width'], json_data['height']))

# %%
drawer = ImageDraw.Draw(image)
for bubble in json_data['bubbles']:
    drawer.ellipse([bubble['center'][0] - bubble['radius'], bubble['center'][1] - bubble['radius'], bubble['center'][0] + bubble['radius'], bubble['center'][1] + bubble['radius']], fill = 1)

# %%
plt.imshow(image)
plt.show()
plt.imshow(Image.open(filepath))

# %%
{'bubbles', 'height', 'width', 'filename'} - set(json_data.keys())
# Out:
# set()

# %% [markdown]
# # Image to circles via Hough

# %%
import cv2 as cv
import numpy as np

# %%
img = cv.imread('data/labels/pristine10.png',0)
img = cv.GaussianBlur(img, (3,3), cv.BORDER_DEFAULT)
cimg = cv.cvtColor(img,cv.COLOR_GRAY2BGR)
circles = cv.HoughCircles(img,cv.HOUGH_GRADIENT,1,20,
                            param1=60,param2=22,minRadius=0,maxRadius=0)
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv.circle(cimg,(i[0],i[1]),2,(0,0,255),3)
plt.imshow(cimg)

# %%
plt.imshow(img)

# %%
circles.shape
# Out:
# (1, 16, 3)
